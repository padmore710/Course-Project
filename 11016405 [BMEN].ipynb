# %% [markdown]
# ## __UNIVERSITY OF GHANA__
# ##### SCHOOL OF ENGINEERING SCIENCES
# ##### BIOMEDICAL ENGINEERING
# ##### SENG 207: PROGRAMMING FOR ENGINEERS
# ##### PROJECT WORK
# ##### QUARSHIE PADMORE MAWUKO
# ##### 11016405

# %% [markdown]
# ### __Introduction:__

# %% [markdown]
# Utilizing the power of the pandas, numpy and matplotlib libraries, this project is aimed to comprehensively explore the red_wine dataset by employing an object-oriented approach. By leveraging the functionalities of these libraries, valuable statistical insights can be extracted and visualizations created to unravel hidden patterns within the dataset.

# %% [markdown]
# #### 1. __*Data Loading and Preprocesses*__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
class RedWine:
    def __init__(self, dataset):
        self.dataset = pd.read_csv(dataset)

    def head_preview(self):
        return self.dataset.head(10)

    def tail_preview(self):
        return self.dataset.tail(20)

    def red_wine_info(self):
        return self.dataset.info()

    def red_wine_description(self):
        return self.dataset.describe()


data = RedWine('red_wine.csv')

# %% [markdown]
# #### 2. __*Data Overview*__

# %%
data.dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# - ##### First ten rows

# %%
data.head_preview()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# - ##### Last twenty rows

# %%
data.tail_preview()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %% [markdown]
# #### 3. __*Statistical Data Analysis*__

# %%
data.red_wine_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
data.red_wine_description()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# #### 4. __*Data Cleaning Processes*__

# %%
class RedWine:
    def __init__(self, dataset):
        self.dataset = pd.read_csv(dataset)

    def fa_fill(column, value):
        data.dataset[column] = data.dataset[column].fillna(value)

    def show_duplicates(self):
        return self.dataset.duplicated()

    def remove_duplicates(self):
        return self.dataset.drop_duplicates()  
        
data = RedWine('red_wine.csv')

# %%
RedWine.fa_fill('fixed acidity', 8.318335)

# %%
RedWine.fa_fill('volatile acidity', 0.527747)

# %%
RedWine.fa_fill('chlorides', 0.087476)

# %%
RedWine.fa_fill('free sulfur dioxide', 15.867334)

# %%
RedWine.fa_fill('density', 0.996746)

# %%
RedWine.fa_fill('quality', 5.635795)

# %%
data.dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
data.dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740318          0.179036     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047058            10.455756             32.895324     0.001887
# ...

# %% [markdown]
# #### 5. __*Data visualisation*__

# %%
class RedWine:
    def __init__(self, dataset):
        self.dataset = pd.read_csv('red_wine.csv')
        self.summary = self.dataset.describe()

    def bar_plot(self):
        mean = self.summary.loc['mean']
        stan_dev = self.summary.loc['std']

        plt.figure(figsize=(8, 6))
        mean.plot(kind='bar', yerr=stan_dev, color='skyblue', alpha=0.7, capsize=5)
        plt.title('Mean with Standard Deviation')
        plt.ylabel('Values')
        plt.xlabel('Features')
        plt.xticks(rotation=45)
        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

    def box_plot(self):
        min_val = self.summary.loc['min']
        max_val = self.summary.loc['max']
        percentiles = self.summary.loc[['25%', '50%', '75%']]

        stats_data = pd.concat([min_val, max_val, percentiles])
        stats_data = stats_data.T

        plt.figure(figsize=(10, 6))
        stats_data.boxplot()
        plt.title('Min, Max, and Percentiles')
        plt.ylabel('Values')
        plt.xlabel('Statistics')
        plt.xticks(rotation=45)
        plt.grid(axis='y')
        plt.tight_layout()
        plt.show()

        
    def correlation_plot(self):
        correlation = self.dataset.corr()

        plt.figure(figsize=(10, 8))
        plt.imshow(correlation, cmap='coolwarm', interpolation='nearest')
        plt.colorbar()
        plt.title('Correlation Plot')
        plt.xticks(range(len(correlation)), correlation.columns, rotation=90)
        plt.yticks(range(len(correlation)), correlation.columns)
        plt.tight_layout()
        plt.show()
        
data = RedWine('red_wine.csv')

# %% [markdown]
# - ### Bar Chart
# A bar chart to show the average values for different properties, with error bars representing the variability around these averages.

# %%
data.bar_plot()

# %% [markdown]
# - ### Box Plot
# This Box plot represents the range of values (min to max) and the spread of data using percentiles (25%, 50%, 75%) for each feature.

# %%
data.box_plot()

# %% [markdown]
# - ### Correlation Plot
# A correlation plot to visually capture the relationships between variables, where stronger correlations are indicated by warmer colours and values closer to 1. Where as cooler colours

# %%
data.correlation_plot()

# %% [markdown]
# ### __*Conclusion*__

# %% [markdown]
# Employing the object-oriented programming paradigm in this project with the aid of pandas, numpy and matplotlib provided a structured approach to unveiling meaningful insights and several key observations from the red_wine dataset.
